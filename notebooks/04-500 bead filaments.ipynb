# %% [markdown]
# # Introduction
# State notebook purpose here

# %% [markdown]
# ### Imports
# Import libraries and write settings here.

# %%
# Notebooks specific imports
from IPython import get_ipython
ipython = get_ipython()
#Expand notebook display
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Display all cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# autoreload extension
if 'autoreload' not in ipython.extension_manager.loaded:
    # %load_ext autoreload
# %autoreload 2

# Basic useful imports
import re
import time
import yaml
from pprint import pprint
from pathlib import Path
import h5py

# Data manipulation
import numpy as np
from scipy.special import erf
from scipy.integrate import quad

# Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import (Circle, RegularPolygon, FancyArrowPatch, ArrowStyle)
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator, NullFormatter)
import matplotlib.colors as colors

# From alens_analysis.py
import alens_analysis as aa
from alens_analysis.colormaps import register_cmaps
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ### Style settings

# %%
graph_sty = {
    "axes.titlesize": 20,
    "axes.labelsize": 24,
    "lines.linewidth": 2,
    "lines.markersize": 10,
    "xtick.labelsize": 24,
    "ytick.labelsize": 24,
    "font.size": 20,
    "font.sans-serif": 'Helvetica',
    "text.usetex": False,
    'mathtext.fontset': 'cm',
}
plt.style.use(graph_sty)

# %%
register_cmaps()
#plt.rcParams['image.cmap'] = 'emct8'
#plt.rcParams['image.cmap'] = 'warm'
plt.rcParams['image.cmap'] = 'YlOrRd'

# %% [markdown]
# ### Location

# %%
ws_path = Path('/home/alamson/DATA/Chromatin/')
mnt_path = Path.home() / 'projects/DATA/Chromatin/'
ceph_path = Path.home() / 'ceph/DATA/Chromatin/'

# %% [markdown]
# # 500 bead looptails (old)

# %% [markdown]
# ## 500 looptail confined

# %%
data_path = (ws_path /"21-08-06_AMchr1_looptail500_2links_conf")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][:520,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [199,], [49,150], 1,2)
fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=199, hist_max=1.)
fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 500 looptail rigid confined

# %%
data_path = (ws_path /"21-08-06_AMchr1_looptail500_rigid_2links_conf")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][150:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [199,], [49,150], 1,2)
fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1.)
fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 500 back-looptail

# %%
data_path = (ws_path /"21-08-09_AMchr1_Blooptail500_2links")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][:500,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [199,], [49,150], 1,2)
fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=199, hist_max=1.)
fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 500 back-looptail rigid

# %%
data_path = (ws_path /"21-08-09_AMchr1_Blooptail500_rigid_2links")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [199,], [49,150], 1,2)
fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1.)
fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 500 back-looptail confined

# %%
data_path = (ws_path /"21-08-09_AMchr1_Blooptail500_2links_conf")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][:520,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [199,], [49,150], 1,2)
fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=299, hist_max=1.)
fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 500 back-looptail rigid confined

# %%
data_path = (ws_path /"21-08-09_AMchr1_Blooptail500_rigid_2links_conf")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][150:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [199,], [49,150], 1,2)
fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=49, hist_max=1.)
fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# # 500 bead looptails (aLENS)

# %% [markdown]
# ## 500 looptail

# %%
data_path = (ceph_path /"21-08-09_AMchr1_looptail500_2links")
ss_ind = 900
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][150:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [199,], [49,150], 1,2)
fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)
# Out:
# /mnt/home/alamson/projects/analysis/AMSOS_Analysis/alens_analysis/chrom_analysis.py:284: RuntimeWarning: divide by zero encountered in log
#   return np.log(contact_map.mean(axis=-1))
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## 500 looptail rigid (redo with longer rigidity)

# %%
data_path = (ceph_path /"21-08-09_AMchr1_looptail500_rigid_2links")
ss_ind = 900
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][150:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [199,], [49,150], 1,2)
fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 21-08-10_aLchr1_3looptail500

# %%
data_path = (ceph_path /"21-08-10_aLchr1_3looptail500")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [49,150], [49,150], 1,2)
fig1, ax1 = aa.make_hic_plot(com_arr, log_contact_avg_mat, vmin=-7)
#fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## 21-08-10_aLchr1_3looptail500_rigid

# %%
data_path = (ceph_path /"21-08-10_aLchr1_3looptail500_rigid")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [49,150], [49,150], 1,2)
fig1, ax1 = aa.make_hic_plot(com_arr, log_contact_avg_mat, vmin=-7)
#fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 21-08-10_aLchr1_3looptail500_conf

# %%
data_path = (ceph_path /"21-08-10_aLchr1_3looptail500_conf")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [49,150], [49,150], 1,2)
fig1, ax1 = aa.make_hic_plot(com_arr, log_contact_avg_mat, vmin=-7)
#fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 21-08-10_aLchr1_3looptail500_rigid_conf

# %%
data_path = (ceph_path /"21-08-10_aLchr1_3looptail500_rigid_conf")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [49,150], [49,150], 1,2)
fig1, ax1 = aa.make_hic_plot(com_arr, log_contact_avg_mat, vmin=-7)
#fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)


#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 21-08-12_aLchr1_2looptail500_rigid

# %%
data_path = (ceph_path /"21-08-12_aLchr1_2looptail500_rigid")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][:,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [49,150], [49,150], 1,2)
fig1, ax1 = aa.make_hic_plot(com_arr, log_contact_avg_mat, vmin=-7)
#fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 21-08-13_aLchr1_looptail500_hairpin10_bot

# %%
data_path = (ceph_path /"21-08-13_aLchr1_looptail500_hairpin10_bot")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][150:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [49,150], [49,150], 1,2)
fig1, ax1 = aa.make_hic_plot(com_arr, log_contact_avg_mat, vmin=-7)
#fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 21-08-13_aLchr1_looptail500_hairpin10_mid

# %%
data_path = (ceph_path /"21-08-13_aLchr1_looptail500_hairpin10_mid")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][150:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [49,150], [49,150], 1,2)
fig1, ax1 = aa.make_hic_plot(com_arr, log_contact_avg_mat, vmin=-7)
#fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 21-08-13_aLchr1_looptail500_hairpin10_top

# %%
data_path = (ceph_path /"21-08-13_aLchr1_looptail500_hairpin10_top")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][150:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [49,150], [49,150], 1,2)
fig1, ax1 = aa.make_hic_plot(com_arr, log_contact_avg_mat, vmin=-7)
#fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 21-08-17_aLchr1_looptail500_3base

# %%
data_path = (ceph_path /"21-08-17_aLchr1_looptail500_3base")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][150:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [49,150], [49,150], 1,2)
fig1, ax1 = aa.make_hic_plot(com_arr, log_contact_avg_mat, vmin=-7)
#fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 21-08-17_aLchr1_looptail500_3base_rigid

# %%
data_path = (ceph_path /"21-08-17_aLchr1_looptail500_3base_rigid")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][150:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [49,150], [49,150], 1,2)
fig1, ax1 = aa.make_hic_plot(com_arr, log_contact_avg_mat, vmin=-7)
#fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 21-08-17_aLchr1_Blooptail500_3base

# %%
data_path = (ceph_path /"21-08-17_aLchr1_Blooptail500_3base")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][150:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [49,150], [49,150], 1,2)
#fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
fig1, ax1 = aa.make_hic_plot(com_arr, log_contact_avg_mat, vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# ## 21-08-17_aLchr1_Blooptail500_3base_rigid (redo)

# %%
data_path = (ceph_path /"21-08-17_aLchr1_Blooptail500_3base_rigid")
ss_ind = 600
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:]
    sy_dat = h5_data['raw_data']['sylinders'][150:350,:,ss_ind:]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]


log_contact_avg_mat = aa.get_time_avg_contact_mat(com_arr, avg_block_step = 1)
#mode_mat = get_rouse_modes(com_arr)

# Graphing
#fig0, ax0 = aa.make_segment_distr_graphs(com_arr, [49,150], [49,150], 1,2)
fig1, ax1 = aa.make_min_distr_plots(com_arr, log_contact_avg_mat, rel_ind=50, hist_max=1., vmin=-7)
#fig2, ax2 = aa.make_rog_vs_time_graph(time_arr, com_arr)
fig1, ax1 = aa.make_hic_plot(com_arr, log_contact_avg_mat, vmin=-7)

#fig2, ax2 = make_rouse_analysis_plots(time_arr, mode_mat, nbeads, max_ind=50)

# %% [markdown]
# # Conclusions and Next Steps
