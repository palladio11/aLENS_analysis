# %% [markdown]
# # Introduction
# State notebook purpose here

# %% [markdown]
# ### Imports
# Import libraries and write settings here.

# %%
# Notebooks specific imports
from IPython import get_ipython
ipython = get_ipython()
#Expand notebook display
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Display all cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# autoreload extension
if 'autoreload' not in ipython.extension_manager.loaded:
    # %load_ext autoreload
# %autoreload 2

# Basic useful imports
import re
import time
import yaml
from pprint import pprint
from pathlib import Path
import h5py

# Data manipulation
import numpy as np
from scipy.special import erf
from scipy.integrate import quad

# Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import (Circle, RegularPolygon, FancyArrowPatch, ArrowStyle)
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator, NullFormatter)
import matplotlib.colors as colors
from cycler import cycler

# From AMSOS_analysis.py
import amsos_analysis as aa
from amsos_analysis.colormaps import register_cmaps
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ### Style settings

# %%
graph_sty = {
    "axes.titlesize": 20,
    "axes.labelsize": 24,
    "lines.linewidth": 2,
    "lines.markersize": 10,
    "xtick.labelsize": 24,
    "ytick.labelsize": 24,
    "font.size": 20,
    "font.sans-serif": 'Helvetica',
    "text.usetex": False,
    'mathtext.fontset': 'cm',
}
plt.style.use(graph_sty)

#plt.rcParams['axes.prop_cycle'] = 'jet'

# %% [markdown]
# ### Location

# %%
ws_path = Path('/home/alamson/DATA/Chromatin/')
mnt_path = Path.home() / 'projects/DATA/Chromatin/'
ceph_path = Path.home() / 'ceph/DATA/Chromatin/'

# %% [markdown]
# # Functions

# %%
def plot_spring_lengths(time, com_arr, start_bead=0, end_bead=None):
    fig, ax = plt.subplots(1,1, figsize=(10,6))
    cycle_min = 1
    cycle_max = 1000
    cycle_step = 25
    
    colormap = plt.get_cmap('plasma').reversed()
    
    if not end_bead:
        bead_list = list(range(com_arr.shape[0]))
    else:
        bead_list = list(range(start_bead, end_bead-1))
    custom_cycler = (cycler(color=[colormap(k) for k in np.linspace(0,1, int(cycle_max/cycle_step))]))
    ax.set_prop_cycle(custom_cycler)
    spring_len_arr = np.linalg.norm(com_arr[1:, :, :] - com_arr[:-1, :, :], axis=1)
    
    for i in range(cycle_min, cycle_max, cycle_step):
        ax.plot(bead_list, spring_len_arr[:, i], label=f"Time {time[i]} sec")
    #ax.legend(bbox_to_anchor=(1.1, 1.05))
    normalize = colors.Normalize(vmin=time[0], vmax=time[-1])
    fig.colorbar(mpl.cm.ScalarMappable( cmap=colormap, norm=normalize),
             ax=ax, label='Seconds')
    
    ax.set_ylabel('Spring length ($\mu$m)')
    ax.set_xlabel('Bead index')

# %%
def plot_stress_vs_time(time, stress_arr):
    fig, ax = plt.subplots(1,1, figsize=(8,6))
    cycle_min = 0
    cycle_max = 1001
    cycle_step = 25
    
    
    colormap = plt.get_cmap('plasma').reversed()
    custom_cycler = (cycler(color=[colormap(k) for k in np.linspace(0,1, int(cycle_max/cycle_step))]))
    ax.set_prop_cycle(custom_cycler)
    #ax.plot(time, stress_arr[0,0,:])
    #ax.set_prop_cycle(custom_cycler)
    #spring_len_arr = np.linalg.norm(com_arr[1:, :, :] - com_arr[:-1, :, :], axis=1)
    for i in range(cycle_min, cycle_max, cycle_step):
        ax.plot(time[i:i+cycle_step], stress_arr[0,0,i:i+cycle_step])
    ax.set_xlabel("Time (sec)")
    ax.set_ylabel("Stress (pN$\cdot\mu$m$^{-2}$)")
    
    #for i in range(cycle_min, cycle_max, cycle_step):
        #ax.plot(spring_len_arr[0,0], label=f"Time {time[i]} sec")
    #ax.legend(bbox_to_anchor=(1.1, 1.05))
    #fig.colorbar(mpl.cm.ScalarMappable( cmap=colormap),
             #ax=ax, label='Seconds')

# %% [markdown]
# # Results/Graphs

# %% [markdown]
# ## Extensile spring

# %%
data_path = (ws_path /"21-11-04_aLchr1_NBline200_diffSpring_noSteric")

ss_ind = 0
end_ind = -1
start_bead = 40
end_bead = 62
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:end_ind]
    print(time_arr.size)
    sy_dat = h5_data['raw_data']['sylinders'][start_bead:end_bead,:,ss_ind:end_ind]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]
    plot_spring_lengths(time_arr, com_arr, start_bead, end_bead)
    plot_stress_vs_time(time_arr, h5_data['bilateral_stress'][:,:,ss_ind:end_ind] + h5_data['collision_stress'][:,:,ss_ind:end_ind])
    #sep_dist_mat = aa.get_sep_dist_mat(h5_data, ss_ind, bead_range=[start_bead,end_bead])
# Out:
# 1001

# %% [markdown]
# ## Contractile spring

# %%
data_path = (ws_path /"21-11-04_aLchr1_NBline100_diffSpring_noSteric_contract")

ss_ind = 0
end_ind = -1
start_bead = 40
end_bead = 62
with h5py.File(next(data_path.glob('*.h5')), 'r+') as h5_data:
    time_arr = h5_data['time'][ss_ind:end_ind]
    print(time_arr.size)
    sy_dat = h5_data['raw_data']['sylinders'][start_bead:end_bead,:,ss_ind:end_ind]
    com_arr = .5 * (sy_dat[:, 2:5, :] + sy_dat[:, 5:8, :])
    nbeads = com_arr.shape[0]
    plot_spring_lengths(time_arr, com_arr, start_bead, end_bead)
    plot_stress_vs_time(time_arr, h5_data['bilateral_stress'][:,:,ss_ind:end_ind] + h5_data['collision_stress'][:,:,ss_ind:end_ind])
    #sep_dist_mat = aa.get_sep_dist_mat(h5_data, ss_ind, bead_range=[start_bead,end_bead])
# Out:
# 1001

# %% [markdown]
# # Continuum calculations

# %%
def A_delta_form(beta, kappa, l_bar):
    if beta < 0.:
        return 0.
    if beta == 0.:
        return .5*l_bar*np.exp(-kappa*beta)
    return l_bar*np.exp(-kappa*beta)
vA_delta_form = np.vectorize(A_delta_form,otypes=[float])

def Aprime_delta_form(beta, kappa, l_bar):
    if beta < 0.:
        return 0.
    if beta == 0.:
        return l_bar*( 1. - .5*kappa*np.exp(-kappa*beta))
    return -kappa*l_bar*np.exp(-kappa*beta)

vAprime_delta_form = np.vectorize(Aprime_delta_form,otypes=[float])

# %%
fig, axarr = plt.subplots(1,2, figsize=(16,6))
axarr[1].set_xlabel(r" $\beta $ ")
axarr[0].set_ylabel(r" $A / \ell_{\infty}$ ")
axarr[1].set_ylabel(r" $A' / \ell_{\infty}$ ")
beta = np.linspace(-2.,6., 100)
A_delta2 = vA_delta_form(beta, 1., 2.)
A_delta3 = vA_delta_form(beta, 1., 3.)
A_delta_k2 = vA_delta_form(beta, 2., 2.)
axarr[0].plot(beta, A_delta2, label=r'$\kappa=1, \ell_{\infty}=2$')
axarr[0].plot(beta, A_delta3, label=r'$\kappa=1, \ell_{\infty}=3$')
axarr[0].plot(beta, A_delta_k2, label=r'$\kappa=2, \ell_{\infty}=2$')
axarr[0].legend()
Ap_delta2 = vAprime_delta_form(beta, 1., 2.)
A_delta3 = vA_delta_form(beta, 1., 3.)
A_delta_k2 = vA_delta_form(beta, 2., 2.)
axarr[1].plot(beta, Ap_delta2, label=r'$\kappa=1, \ell_{\infty}=2$')

plt.tight_layout()
# Out:
# Text(0.5, 0, ' $\\beta $ ')
# Text(0, 0.5, ' $A / \\ell_{\\infty}$ ')
# Text(0, 0.5, " $A' / \\ell_{\\infty}$ ")

# %% [markdown]
# # Conclusions and Next Steps
